# %% [markdown]
# # Assignment

# %%
import pandas as pd

# %%
df = pd.read_csv('carprice.csv')

# %%
df.head()
# Out:
#    symboling               CarName fueltype aspiration doornumber  \
# 0          2           audi 100 ls      gas        std       four
# 1          0           peugeot 504      gas        std       four
# 2          3  mitsubishi outlander      gas      turbo        two
# 3          1         toyota corona      gas        std        two
# 4          2       toyota cressida      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0        sedan        fwd          front       99.8      176.6  ...
# 1        wagon        rwd          front      114.2      198.9  ...
# 2    hatchback        fwd          front       95.9      173.2  ...
# 3    hatchback        fwd          front       95.7      158.7  ...
# 4  convertible        rwd          front       98.4      176.2  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0         109        mpfi       3.19   3.40             10.0         102
# ...

# %% [markdown]
# # Question
# Give me some insights from this data. (Totally open ended, dazzle me with your brilliance ^_^ )
#
# Find me something meaningful that will help me as a business owner.
#
# ![](https://media.giphy.com/media/3oEjHAWsCGowjkc3Ha/giphy.gif)

# %% [markdown]
# # Answer

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df['fueltype']
# Out:
# 0         gas
# 1         gas
# 2         gas
# 3         gas
# 4         gas
#         ...
# 148       NaN
# 149       gas
# 150    diesel
# 151       gas
# 152    diesel
# Name: fueltype, Length: 153, dtype: object

# %%
df['fueltype'].value_counts()
# Out:
# gas       133
# diesel     17
# Name: fueltype, dtype: int64

# %%
df['fueltype'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='fueltype'>

# %% [markdown]
# # 1. There are more number of gas cars than diesel cars.

# %%
df.groupby('fueltype').mean()['enginesize'].plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.groupby('fueltype').mean()['enginesize'].plot(kind='pie')
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 2. Diesel cars have bigger engines in comparison to gas cars.

# %%
df.groupby('fueltype').mean()['horsepower'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='horsepower'>

# %% [markdown]
# # 3. Gas cars produce more horsepower than diesel cars.

# %%
df['horsepower'].max()
# Out:
# 207

# %%
HR = df.groupby('horsepower')

# %%
HR.get_group(207)
# Out:
#     symboling            CarName fueltype aspiration doornumber      carbody  \
# 7           3     porsche boxter      gas        std        two  convertible
# 39          3    porsche cayenne      gas        std        two      hardtop
# 43          3  porcshce panamera      gas        std        two      hardtop
#
#    drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 7         rwd           rear       89.5      168.9  ...         194
# 39        rwd           rear       89.5      168.9  ...         194
# 43        rwd           rear       89.5      168.9  ...         194
#
#     fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  \
# 7         mpfi       3.74    2.9              9.5         207  5900.0
# 39        mpfi       3.74    2.9              9.5         207  5900.0
# 43        mpfi       3.74    2.9              9.5         207  5900.0
#
#     citympg  highwaympg    price
# 7      17.0        25.0  37028.0
# ...

# %% [markdown]
# # 4. Above we can see Porsche company dominates the highest horsepower              place with 3 of their cars having max horsepower in this dataset which is            207. The only difference between the three cars is in their car body and                price.

# %%
df['price'].max()
# Out:
# 45400.0

# %%
PR = df.groupby('price')

# %%
PR.get_group(45400)
# Out:
#     symboling                          CarName fueltype aspiration doornumber  \
# 71          1  buick regal sport coupe (turbo)      gas        std        two
#
#     carbody drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 71  hardtop        rwd          front      112.0      199.2  ...         304
#
#     fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  \
# 71        mpfi        3.8   3.35              8.0         184  4500.0
#
#     citympg  highwaympg    price
# 71     14.0        16.0  45400.0
#
# [1 rows x 25 columns]

# %% [markdown]
# # 5. Most expensive car in this dataset is Buick regal sport coupe(turbo).

# %%
df['price'].min()
# Out:
# 5118.0

# %%
PR.get_group(5118)
# Out:
#     symboling CarName fueltype aspiration doornumber    carbody drivewheel  \
# 44          2  subaru      gas        std        two  hatchback        fwd
#
#    enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 44          front       93.7      156.9  ...          97        2bbl
#
#     boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 44       3.62   2.36              9.0          69     NaN     31.0
#
#     highwaympg   price
# 44        36.0  5118.0
#
# [1 rows x 25 columns]

# %% [markdown]
# # 6. Cheapest car in this dataset is Subaru.

# %%
plt.scatter(df['horsepower'],df['price'])

# %%
plt.scatter(df['enginesize'],df['price'])

# %% [markdown]
# # 7. Above we can see there is a positive relationship between price and engine size.

# %% [markdown]
# # 8. Most cars have price less than 20,000 and engine size less than 180.

# %% [markdown]
# # 9. Through this scatter plot we can see the relationship between horsepower and price and see there is a postive relationship between the two.

# %% [markdown]
# # 10. We can also see above that most cars are priced below 20,000 and have horsepower less than 120.

# %%
df['carbody'].value_counts()
# Out:
# sedan          72
# hatchback      51
# wagon          21
# hardtop         5
# convertible     4
# Name: carbody, dtype: int64

# %%
df['carbody'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 11. There are most sedan cars in this dataset and least covertibles.

# %%
df.groupby('carbody')['price'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='carbody'>

# %% [markdown]
# # 12. Above we can see that Convertible and hardtop cars have the highest prices and hatchback have the least.

# %%
df.groupby('carbody').mean()['enginesize'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='carbody'>

# %% [markdown]
# # 13. Above we can see hardtop cars have the biggest engine size and hatchback have the least.

# %%
df.groupby('carbody').mean()['horsepower'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='carbody'>

# %% [markdown]
# # 14. Above we can see hardtop cars have the highest horsepower and hatchback have the lowest horsepower (slightly lower than sedan and wagon cars).

# %%
df['cylindernumber'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 15. Above we can see that most cars have 4 cylinders by a high margin and least cars have 3 cylinders.

# %%
df.groupby('cylindernumber')['carbody'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='cylindernumber,carbody'>

# %% [markdown]
# # 16. Above we can see Sedan cars with 4 cylinders are highest in number.

# %%
df.groupby('drivewheel')['enginelocation'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='drivewheel,enginelocation'>

# %% [markdown]
# # 17. Above we can see most cars have fwd (front wheel drive) with engine in the front.
